# %%
age = int (input("Enter your age : "))
ticket = True
if age >= 18 :
    print("You can watch the movie")
    if age >= 18 :
        print("Check your id ")
elif age < 15:
    print ("You can watch the movie with parents ")
else:
    print("Not allowed")
